# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_filename = "Daily Update Data Agregat Covid-19 Jakarta.xlsx"

# %%
dataset = []

# %%
for i in range (0,10): 
    sheet = pd.read_excel(data_filename,sheet_name=i,engine="openpyxl")
    dataset.append(sheet)

# %% [markdown]
# # Dataset variable information
# - **DJ** = Data Jakarta
# - **DIJ** = Data Indonesia and Jakarta
# - **Suspek** = Data Suspek
# - **RDT ab** = Data  RDT ab
# - **RDT ag** = Data RDT ag
# - **HL** = Data Hasil Lab
# - **V** = Data vaksinasi
# - **P** = Data pemakaman
# - **VW** = Data vaksinasi wilayah
# - **DVWI** = Daily vaksinasi wilayah

# %%
df_DJ = dataset[0]
df_DIJ = dataset[1]
df_Suspek = dataset[2]
df_RDTab = dataset[3]
df_RDTag = dataset[4]
df_HL = dataset[5]
df_V = dataset[6]
df_P = dataset[7]
df_VW = dataset[8]
df_DVW = dataset[9]

# %%
idx = 0 
for i in dataset : 
    print(f"dataset ke dari excel {idx}: ")
    print(i.info())
    print()
    idx+=1
# Out:
# dataset ke dari excel 0:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Tanggal                             503 non-null    datetime64[ns]
#  1   Jam                                 484 non-null    float64
#  2   Tanggal Jam                         503 non-null    datetime64[ns]
#  3   Total Pasien                        503 non-null    int64
#  4   Sembuh                              503 non-null    int64
#  5   Meninggal                           503 non-null    int64
#  6   Self Isolation                      503 non-null    int64
#  7   Masih Perawatan                     503 non-null    int64
#  8   Belum Diketahui (masih verifikasi)  0 non-null      float64
#  9   Menunggu Hasil                      6 non-null      float64
# ...

# %% [markdown]
# ## Cleanup and rearange data
# ### Cleanup RDT ab dataset

# %%
df_RDTab = df_RDTab.loc[:, 'Tanggal':'Positivity Rate']

# %%
df_RDTab.head()
# Out:
#      Tanggal  Reaktif  Non-Reaktif  Total  Positivity Rate
# 0 2020-03-27      124        10839  10963         0.011311
# 1 2020-03-28      149        11858  12007         0.012409
# 2 2020-03-29      206        14808  15014         0.013721
# 3 2020-03-30      290        17619  17909         0.016193
# 4 2020-03-31      307        18242  18549         0.016551

# %% [markdown]
# ### Cleanup RDT ag dataset

# %%
df_RDTag.drop(columns=["No "],inplace=True)
df_RDTag.head()
# Out:
#          Tgl  EIS Positif  EIS Negatif  EIS Total  NAR Positivity Rate  \
# 0 2021-01-01           76         1116       1192             0.063758
# 1 2021-01-02           76         1116       1192             0.063758
# 2 2021-01-03          100         1699       1799             0.055586
# 3 2021-01-04          100         1699       1799             0.055586
# 4 2021-01-05          100         1699       1799             0.055586
#
#    NAR Positif  NAR Negatif  NAR Total  Excel Positivity Rate  Excel Positif  \
# 0            0            0          0                    NaN              0
# 1            0            0          0                    NaN              0
# 2            0            0          0                    NaN              0
# 3            0            0          0                    NaN              0
# 4            0            0          0                    NaN              0
#
#    ...  Excel Total  Excel Positivity Rate.1  TotalDKI Tes Harian  \
# ...

# %% [markdown]
# ### Cleaning and re-arange Vaksin dataset

# %%
df_V.fillna("",inplace=True)

# %%
df_V.columns = df_V.iloc[1] + " | " + df_V.iloc[2] + " | " + df_V.iloc[3]

# %%
df_V.drop([0,1,2,3],axis=0,inplace=True)

# %%
df_V.rename(columns={df_V.columns[0] : "Tanggal"},inplace=True)

# %%
df_V.head()
# Out:
#                Tanggal DKI | Tenaga Kesehatan | Target Vaksinasi  \
# 4  2021-03-05 00:00:00                                    112301
# 5  2021-03-06 00:00:00                                    112301
# 6  2021-03-07 00:00:00                                    112301
# 7  2021-03-08 00:00:00                                    112301
# 8  2021-03-09 00:00:00                                    112301
#
#   DKI | Tenaga Kesehatan | Vaksinasi 1 DKI | Tenaga Kesehatan | Vaksinasi 2  \
# 4                               141425                                91078
# 5                               144046                                91379
# 6                               177126                                91460
# 7                               181237                                92988
# 8                               113326                                89984
#
#   DKI | Tenaga Kesehatan | Persentase 1 DKI | Tenaga Kesehatan | Persentase 2  \
# ...

# %% [markdown]
# ### Data Jakarta

# %%
df_DJ = df_DJ.loc[:, :'Belum Ada Data']

# %%
df_DJ = df_DJ.dropna(axis=1, how='all')

# %%
df_DJ.head()
# Out:
#      Tanggal  Jam         Tanggal Jam  Total Pasien  Sembuh  Meninggal  \
# 0 2020-03-01  NaN 2020-03-01 18:00:00             0       0          0
# 1 2020-03-02  NaN 2020-03-02 18:00:00             0       0          0
# 2 2020-03-03  NaN 2020-03-03 18:00:00             3       0          1
# 3 2020-03-04  NaN 2020-03-04 18:00:00             3       0          1
# 4 2020-03-05  NaN 2020-03-05 18:00:00             7       0          3
#
#    Self Isolation  Masih Perawatan  Menunggu Hasil  \
# 0               0                0             NaN
# 1               0                0             NaN
# 2               0                2             NaN
# 3               0                2             NaN
# 4               0                4             NaN
#
#    Tenaga Kesehatan Terinfeksi  Positif Harian  Positif Aktif  Sembuh Harian  \
# 0                          NaN               0              0              0
# ...

# %%
df_DJ.tail()
# Out:
#        Tanggal  Jam         Tanggal Jam  Total Pasien  Sembuh  Meninggal  \
# 498 2021-07-12  8.0 2021-07-12 08:00:00        677061  584912       9462
# 499 2021-07-13  8.0 2021-07-13 08:00:00        689243  589486       9541
# 500 2021-07-14  8.0 2021-07-14 08:00:00        701910  592556       9603
# 501 2021-07-15  8.0 2021-07-15 08:00:00        714601  595582       9743
# 502 2021-07-16  8.0 2021-07-16 08:00:00        727016  604034       9845
#
#      Self Isolation  Masih Perawatan  Menunggu Hasil  \
# 498           66581            16106             NaN
# 499           71848            18368             NaN
# 500           78571            21180             NaN
# 501           86298            22978             NaN
# 502           88294            24843             NaN
#
#      Tenaga Kesehatan Terinfeksi  Positif Harian  Positif Aktif  \
# 498                          NaN           14619          82687
# 499                          NaN           12182          90216
# ...

# %%
df_DJ['Positif Harian'].describe()
# Out:
# count      503.000000
# mean      1445.359841
# std       2245.317226
# min          0.000000
# 25%        219.000000
# 50%        890.000000
# 75%       1447.500000
# max      14619.000000
# Name: Positif Harian, dtype: float64

# %%
plt.boxplot(df_DJ['Positif Harian'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1280b9340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1280b99a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1283cefd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1280ae100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1280ae490>],
#  'means': []}

# %%
df_DJ['Positif Harian'] = sorted(df_DJ['Positif Harian'])

# %%
q1, q3= np.percentile(df_DJ['Positif Harian'],[25,75])

# %%
q1,q3
# Out:
# (219.0, 1447.5)

# %%
iqr=q3-q1

# %%
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

# %%
lower_bound, upper_bound
# Out:
# (-1623.75, 3290.25)

# %%
df_DJ['Positif Harian']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#        ...
# 498    12920
# 499    12974
# 500    13112
# 501    13133
# 502    14619
# Name: Positif Harian, Length: 503, dtype: int64

# %%
df_DJ["Positif Harian"][(df_DJ["Positif Harian"] < lower_bound) | (df_DJ["Positif Harian"] > upper_bound)].count()
# Out:
# 47

# %%
corr = df_DJ.corr()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(corr["Positif Harian"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.9]
relevant_features
# Out:
# Masih Perawatan                0.927469
# Menunggu Hasil                 0.929007
# Tenaga Kesehatan Terinfeksi    0.902576
# Positif Harian                 1.000000
# Positif Aktif                  0.916747
# Name: Positif Harian, dtype: float64

# %%
print(df_DJ[["Masih Perawatan","Menunggu Hasil"]].corr())
print("")
print(df_DJ[["Masih Perawatan","Tenaga Kesehatan Terinfeksi"]].corr())
print("")
print(df_DJ[["Masih Perawatan","Positif Aktif"]].corr())
print("")
print(df_DJ[["Menunggu Hasil","Tenaga Kesehatan Terinfeksi"]].corr())
print("")
print(df_DJ[["Menunggu Hasil","Positif Aktif"]].corr())
print("")
print(df_DJ[["Tenaga Kesehatan Terinfeksi","Positif Aktif"]].corr())
print("")
# Out:
#                  Masih Perawatan  Menunggu Hasil
# Masih Perawatan         1.000000        0.994639
# Menunggu Hasil          0.994639        1.000000
#
#                              Masih Perawatan  Tenaga Kesehatan Terinfeksi
# Masih Perawatan                     1.000000                     0.962064
# Tenaga Kesehatan Terinfeksi         0.962064                     1.000000
#
#                  Masih Perawatan  Positif Aktif
# Masih Perawatan         1.000000       0.951064
# Positif Aktif           0.951064       1.000000
#
#                              Menunggu Hasil  Tenaga Kesehatan Terinfeksi
# Menunggu Hasil                     1.000000                     0.969053
# Tenaga Kesehatan Terinfeksi        0.969053                     1.000000
#
#                 Menunggu Hasil  Positif Aktif
# Menunggu Hasil        1.000000       0.984758
# Positif Aktif         0.984758       1.000000
#
#                              Tenaga Kesehatan Terinfeksi  Positif Aktif
# ...

# %%
df_RDTab.tail()
# Out:
#        Tanggal  Reaktif  Non-Reaktif   Total  Positivity Rate
# 473 2021-07-13    40491       690683  731174         0.055378
# 474 2021-07-14    40496       690700  731196         0.055383
# 475 2021-07-15    40516       690731  731247         0.055407
# 476 2021-07-16    40523       690738  731261         0.055415
# 477 2021-07-17    40523       690747  731270         0.055415

# %%
df_RDTag.tail()
# Out:
#        Tanggal  EIS Positif  EIS Negatif  EIS Total  NAR Positivity Rate  \
# 193 2021-07-13         6427       101603     108030             0.059493
# 194 2021-07-14         6547       102042     108589             0.060292
# 195 2021-07-15         6640       102533     109173             0.060821
# 196 2021-07-16         6725       102821     109546             0.061390
# 197 2021-07-17         6827       103215     110042             0.062040
#
#      NAR Positif  NAR Negatif  NAR Total  Excel Positivity Rate  \
# 193        27753       467065     494818               0.056087
# 194        28429       471503     499932               0.056866
# 195        29117       476288     505405               0.057611
# 196        29942       482374     512316               0.058444
# 197        30725       489385     520110               0.059074
#
#      Excel Positif  ...  Excel Total  Excel Positivity Rate.1  \
# 193             42  ...         1016                 0.041339
# ...

# %%
df_RDTag = df_RDTag.rename(columns={"Tgl": "Tanggal"})

# %%
df_RD = df_RDTab.merge(df_RDTag, how='inner', on='Tanggal')

# %%
df_RD = df_RD.merge(df_DJ, how='inner', on='Tanggal')

# %%
df_RD.tail()
# Out:
#        Tanggal  Reaktif  Non-Reaktif   Total  Positivity Rate  EIS Positif  \
# 192 2021-07-12    40491       690683  731174         0.055378         6297
# 193 2021-07-13    40491       690683  731174         0.055378         6427
# 194 2021-07-14    40496       690700  731196         0.055383         6547
# 195 2021-07-15    40516       690731  731247         0.055407         6640
# 196 2021-07-16    40523       690738  731261         0.055415         6725
#
#      EIS Negatif  EIS Total  NAR Positivity Rate  NAR Positif  ...  \
# 192       101076     107373             0.058646        26803  ...
# 193       101603     108030             0.059493        27753  ...
# 194       102042     108589             0.060292        28429  ...
# 195       102533     109173             0.060821        29117  ...
# 196       102821     109546             0.061390        29942  ...
#
#      Self Isolation  Masih Perawatan  Menunggu Hasil  \
# 192           66581            16106             NaN
# ...

# %%
df_RD.groupby(['Tanggal','Positif Kumulatif']).size()
# Out:
# Tanggal     Positif Kumulatif
# 2021-01-01  76                   1
# 2021-01-02  76                   1
# 2021-01-03  100                  1
# 2021-01-04  100                  1
# 2021-01-05  100                  1
#                                 ..
# 2021-07-12  33142                1
# 2021-07-13  34222                1
# 2021-07-14  35018                1
# 2021-07-15  35799                1
# 2021-07-16  36709                1
# Length: 197, dtype: int64

# %%
df_RD.groupby(['Tanggal','Reaktif']).size()
# Out:
# Tanggal     Reaktif
# 2021-01-01  33239      1
# 2021-01-02  33239      1
# 2021-01-03  33239      1
# 2021-01-04  33239      1
# 2021-01-05  37852      1
#                       ..
# 2021-07-12  40491      1
# 2021-07-13  40491      1
# 2021-07-14  40496      1
# 2021-07-15  40516      1
# 2021-07-16  40523      1
# Length: 197, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_RD.groupby(['Tanggal','Reaktif']).count().plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Tanggal,Reaktif'>

# %%
df_RD
# Out:
#        Tanggal  Reaktif  Non-Reaktif    Total  Positivity Rate        Tgl  \
# 0   2020-03-27    124.0      10839.0  10963.0         0.011311        NaT
# 1   2020-03-28    149.0      11858.0  12007.0         0.012409        NaT
# 2   2020-03-29    206.0      14808.0  15014.0         0.013721        NaT
# 3   2020-03-30    290.0      17619.0  17909.0         0.016193        NaT
# 4   2020-03-31    307.0      18242.0  18549.0         0.016551        NaT
# ..         ...      ...          ...      ...              ...        ...
# 671        NaT      NaN          NaN      NaN              NaN 2021-07-13
# 672        NaT      NaN          NaN      NaN              NaN 2021-07-14
# 673        NaT      NaN          NaN      NaN              NaN 2021-07-15
# 674        NaT      NaN          NaN      NaN              NaN 2021-07-16
# 675        NaT      NaN          NaN      NaN              NaN 2021-07-17
#
#      EIS Positif  EIS Negatif  EIS Total  NAR Positivity Rate  ...  \
# ...
